# %% [markdown]
# #### total_survey_221129.csv파일에서
# #### Gender2 -> gender 로 변경
# #### Age2 -> age로 변경

# %%
total_survey_221129_df = pd.read_csv('total_survey_221129.csv', encoding='ansi')
total_survey_221129_df.head()

# %%
survey_gender_age_df = total_survey_221129_df[['gender', 'age']]
survey_gender_age_df

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
import pandas as pd
import numpy as np
import pymysql

# %%
# webtoon_db_connect_str = "mysql+pymysql://jsh:bread!123@localhost/jsh"
webtoon_db_connect_str = "mysql+pymysql://root:1234@localhost/jsh"
webtoon_db_connection = create_engine(webtoon_db_connect_str)
Session = sessionmaker(webtoon_db_connection)

# %%
conn = webtoon_db_connection.connect()

# %%
survey_gender_age_df.to_sql(name="survey_gender_age",con=webtoon_db_connection,if_exists="append",index=False)

# %%
with Session() as session:
    session.commit()
